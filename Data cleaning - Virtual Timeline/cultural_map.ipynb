# %%
import pandas as pd
import numpy as np
import os
import folium
from folium import plugins
import webbrowser
from folium.plugins import HeatMap
import geopandas as gp
import shapefile as shp

# %% [markdown]
# Open the file. Open Public art, Street art, Slave trade to observe what data inside it. Our goal is to cope with the date and positions of arts in Edinburgh.

# %%
#read the file
PublicData = pd.read_csv("Public art.csv")
PublicData
# Out:
#                           Title / subject          y         x       Date  \
# 0               Monument to John Playfair    55.9548 -3.183000     1825-6
# 1              Monument to Dugald Stewart    55.9545 -3.184500       1831
# 2                Monument to Robert Burns    55.9535 -3.178300     1831-9
# 3             Political Martyrs' Monument    55.9534 -3.185800       1844
# 4    Scottish-American Soldiers' Monument    55.9535 -3.186100       1893
# ..                                    ...        ...       ...        ...
# 142                  Crew Building Relief  55.923065 -3.177520  c.1926-32
# 143                 Startled Horse Rising  55.864532 -3.200328       1833
# 144                         William Dick   55.865794 -3.201039       1883
# 145                Sprinting Afghan Hound  55.864975 -3.201746       1996
# 146                                Canter  55.865174 -3.200375     2017/8
#
#              Location                     Artist / designer  \
# 0                 NaN                William Henry Playfair
# 1                 NaN                William Henry Playfair
# 2                 NaN                       Thomas Hamilton
# 3                 NaN                       Thomas Hamilton
# 4                 NaN                  George Edwin Bissell
# ..                ...                                   ...
# 142  King's Buildings  Charles d'Orville Pilkington-Jackson
# 143       Easter Bush                      Sir John Steell
# 144       Easter Bush                           John Rhind
# 145       Easter Bush                Mathew Lane Sanderson
# 146       Easter Bush                           Andy Scott
#
#                                            Type  \
# 0              Square-plan Greek Doric monument
# 1    Circular Greek-revival Corinthian monument
# 2    Circular Greek-revival Corinthian monument
# 3                                       Obelisk
# 4              Statue with subsidiary sculpture
# ..                                          ...
# 142                                         NaN
# 143                                         NaN
# 144                                         NaN
# 145                                         NaN
# 146                                         NaN
#
#                                    Material Dimensions  \
# 0                           Polished ashlar        NaN
# 1                           Polished ashlar        NaN
# 2                          Ashlar sandstone        NaN
# 3                                       NaN        NaN
# 4    Bronze figures on red granite pedestal        NaN
# ..                                      ...        ...
# 142                                     NaN        NaN
# 143                                     NaN        NaN
# 144                                   Stone        NaN
# 145                                  Bronze        NaN
# 146                                     NaN        NaN
#
#                                            Designation  \
# 0                                    Category A-listed
# 1                                    Category A-listed
# 2                                    Category A-listed
# 3    Category A-listed (as part of Old Calton Buria...
# 4    Category A-listed (as part of Old Calton Buria...
# ..                                                 ...
# 142                                                NaN
# 143                                                NaN
# 144                                                NaN
# 145                                                NaN
# 146                                                NaN
#
#                                    Collection  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 142  University of Edinburgh  Art Collection
# 143  University of Edinburgh  Art Collection
# 144  University of Edinburgh  Art Collection
# 145  University of Edinburgh  Art Collection
# 146  University of Edinburgh  Art Collection
#
#                                                  Notes  \
# 0         Incorporated in observatory compound wall[1]
# 1    Based on the Choragic Monument of Lysicrates i...
# 2    Based on the Choragic Monument of Lysicrates i...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 142  The figurative relief carving to the building'...
# 143  Stone sculpture of a horse, lying on the groun...
# 144  Sculpture of former Vetinary surgeon and found...
# 145  Sprinting afghan hound, hair flowing behind it...
# 146                                                NaN
#
#                                                 Images  \
# 0    https://upload.wikimedia.org/wikipedia/commons...
# 1    https://upload.wikimedia.org/wikipedia/commons...
# 2    https://upload.wikimedia.org/wikipedia/commons...
# 3    https://upload.wikimedia.org/wikipedia/commons...
# 4    https://upload.wikimedia.org/wikipedia/commons...
# ..                                                 ...
# 142  https://images.is.ed.ac.uk/luna/servlet/iiif/U...
# 143  https://images.is.ed.ac.uk/luna/servlet/iiif/U...
# 144  https://images.is.ed.ac.uk/luna/servlet/iiif/U...
# 145  https://images.is.ed.ac.uk/luna/servlet/iiif/U...
# 146  https://www.roslininnovationcentre.com/assets/...
#
#                                                 Source
# 0    https://en.wikipedia.org/wiki/List_of_public_a...
# 1    https://en.wikipedia.org/wiki/List_of_public_a...
# 2    https://en.wikipedia.org/wiki/List_of_public_a...
# 3    https://en.wikipedia.org/wiki/List_of_public_a...
# 4    https://en.wikipedia.org/wiki/List_of_public_a...
# ..                                                 ...
# 142                                                NaN
# 143                                                NaN
# 144                                                NaN
# 145                                                NaN
# 146                                                NaN
#
# [147 rows x 14 columns]

# %%
StreetData = pd.read_csv("Street art.csv")
StreetData
# Out:
#                                      name    Category     State  \
# 0                     Leith History Mural  Street art  Existing
# 1                     Horne Terrace Mural  Street art    Erased
# 2   Colinton Station and Tunnel (site of)  Street art  Existing
# 3                       Spylaw park mural  Street art  Existing
# 4                          Never Ordinary  Street art  Existing
# 5                            Capita Mural  Street art  Existing
# 6                          Wildlife Mural  Street art  Existing
# 7                              Etza Skull  Street art  Existing
# 8                        Eduardo Paolozzi  Street art  Existing
# 9                      Gifford Park Mural  Street art  Existing
# 10                  Bongo Club Gate Mural  Street art  Existing
# 11                              Abbeyhill  Street art  Existing
# 12                        Studio 24 mural  Street art  Existing
# 13        4 Doors Down Street Art Project  Street art  Existing
# 14                     The acuatic Leith   Street art  Existing
# 15                          Wronger Rites  Street art  Existing
# 16                         Untitled Mural  Street art  Existing
# 17               Leith Dockers Club Mural  Street art  Existing
# 18                         Untitled Mural  Street art  Existing
# 19                Too Much Fun Club Mural  Street art  Existing
# 20                  The Seven Deadly Sins  Street art    Erased
# 21                        Swanfield Mural  Street art    Erased
# 22     Scotland, together, persevere, NHS  Street art  Existing
# 23                          Armoury mural  Street art  Existing
# 24              Graffiti in Roseburn Park  Street art  Existing
# 25                            Free Speech  Street art  Existing
# 26                                  Unity  Street art  Existing
# 27                            The Protest  Street art  Existing
# 28                               Poseidon  Street art  Existing
# 29                 Figgate Park Wild life  Street art  Existing
# 30                 Figgate Park Wild life  Street art  Existing
# 31                 Figgate Park Wild life  Street art  Existing
# 32                 Figgate Park Wild life  Street art  Existing
#
#                                               Address  \
# 0                      21 N Jct St, Edinburgh EH6 6HW
# 1                 2 Horne Terrace, Edinburgh EH11 1JW
# 2                                  Edinburgh EH13 0JX
# 3                                  Edinburgh EH13 0JX
# 4                  Candlemaker Row, Edinburgh EH1 2QE
# 5                      145 Morrison Street, Edinburgh
# 6                             Bridge 8 Hub, Edinburgh
# 7              Marine Parade Graffiti Wall, Edinburgh
# 8                                     77 Henderson St
# 9           37 Clerk St, Newington, Edinburgh EH8 9JQ
# 10                      66 Cowgate, Edinburgh EH1 1JX
# 11                                       41 Abbeyhill
# 12                 24-26 Calton Rd, Edinburgh EH8 8DP
# 13           20 Maritime Ln, Leith, Edinburgh EH6 6BZ
# 14                                       3 Halmyre St
# 15                                     Dalmeny Street
# 16                                     115 Leith Walk
# 17                              17-17A Academy Street
# 18  Courtyard opposite Links View House, Tolbooth ...
# 19                                        Pilrig Park
# 20             Site of Oregano pizzeria on Leith Walk
# 21                                    Bonnington Road
# 22                                        4 Albert St
# 23                                      Roseburn Park
# 24                                      Roseburn Park
# 25                                           EH14 2AG
# 26                                            EH6 5EL
# 27                                            EH6 5EL
# 28                                            EH5 1ET
# 29                                       Figgate Park
# 30                                       Figgate Park
# 31                                       Figgate Park
# 32                                       Figgate Park
#
#                                                Artist  \
# 0                              Tim Chalk & Paul Grime
# 1                                    Robert Callender
# 2                                    Chris Rutterford
# 3                                 Firhill high school
# 4                                  Paramount Pictures
# 5                                    Chris Rutterford
# 6                                          Rouge Oner
# 7                                                Etza
# 8                                Russell Ian Dempster
# 9                                         Kate George
# 10                                      Kirsty Whiten
# 11                               Fraser Gray and FiST
# 12                                      Sepctrum Arts
# 13                                   Miiss U Kam-Ling
# 14                               Blameless collective
# 15                                      Kirsty Whiten
# 16                                               Elph
# 17                                          Tom Ewing
# 18          Artists' Collective (Design by Tim Chalk)
# 19  The Too Much Fun Club (artists Ross McRae and ...
# 20                                   Guido van Helten
# 21                                    David Wilkinson
# 22                                             Victor
# 23                 Kieran Gorman of Zap Graffiti Arts
# 24  Local children and juniors from Murrayfield DA...
# 25                                     The rebel bear
# 26                                     The rebel bear
# 27                                     The rebel bear
# 28                                     The rebel bear
# 29                                         Paco graff
# 30                                         Paco graff
# 31                                         Paco graff
# 32                                         Paco graff
#
#                                               Summary    Year  \
# 0                                                 NaN     NaN
# 1   On a gable end is an engrossing hyper-realisti...     NaN
# 2                                                 NaN     NaN
# 3   Mural by Firrhill high school. Commisioned by ...     NaN
# 4                                                 NaN     NaN
# 5                                                 NaN     NaN
# 6                                                 NaN     NaN
# 7                                                 NaN     NaN
# 8                                                 NaN     NaN
# 9                                                 NaN     NaN
# 10                                                NaN     NaN
# 11                                                NaN     NaN
# 12                                                NaN     NaN
# 13                                                NaN     NaN
# 14                                                NaN     NaN
# 15                                                NaN  2015.0
# 16                                                NaN  2016.0
# 17                                                NaN  2013.0
# 18                                                NaN  1984.0
# 19                                                NaN     NaN
# 20                                                NaN     NaN
# 21                                                NaN  1986.0
# 22                                                NaN  2020.0
# 23  The initiative for the work in Roseburn Park c...  2019.0
# 24  "Official" graffiti by the Friends of Roseburn...  2011.0
# 25                                                NaN  2020.0
# 26                                                NaN  2020.0
# 27                                                NaN  2020.0
# 28                                                NaN  2019.0
# 29                                                NaN  2015.0
# 30                                                NaN  2015.0
# 31                                                NaN  2015.0
# 32                                                NaN  2015.0
#
#                                               website          Y         X  \
# 0                                                 NaN  55.975789 -3.179434
# 1   https://www.edinburghnews.scotsman.com/news/pe...  55.939979 -3.213681
# 2   https://www.edinburghnews.scotsman.com/news/pe...  55.907897 -3.260054
# 3   https://edwinglucas.com/news-spylaw-park-mural...  55.907430 -3.260413
# 4                                                 NaN  55.947394 -3.192042
# 5                                                 NaN  55.945689 -3.211781
# 6                                                 NaN  55.918382 -3.299983
# 7                                                 NaN  55.979919 -3.185874
# 8   https://www.scotsman.com/arts-and-culture/scot...  55.974585 -3.172151
# 9                                                 NaN  55.942136 -3.182363
# 10                                                NaN  55.948197 -3.192164
# 11                                                NaN  55.954961 -3.172947
# 12  https://urbankulturblog.com/2016/12/11/studio-...  55.952640 -3.179313
# 13                                                NaN  55.974766 -3.168192
# 14             https://www.leithlate.co.uk/what-we-do  55.968044 -3.170300
# 15                                                NaN  55.964819 -3.174445
# 16                                                NaN  55.968598 -3.173372
# 17                                                NaN  55.970740 -3.170118
# 18   https://www.picuki.com/media/1728193426699550571  55.973644 -3.170588
# 19                                                NaN  55.967603 -3.179904
# 20                                                NaN  55.965529 -3.175854
# 21                                                NaN  55.971693 -3.176815
# 22                                                NaN  55.962692 -3.178664
# 23  http://www.friendsofroseburnpark.org.uk/2019/0...  55.945211 -3.240524
# 24  http://www.friendsofroseburnpark.org.uk/2011/0...  55.945270 -3.240296
# 25          https://www.instagram.com/the.rebel.bear/  55.926331 -3.269629
# 26          https://www.instagram.com/the.rebel.bear/  55.966275 -3.175770
# 27          https://www.instagram.com/the.rebel.bear/  55.967740 -3.173990
# 28          https://www.instagram.com/the.rebel.bear/  55.980129 -3.218357
# 29               https://www.flickr.com/photos/tayac/  55.951000 -3.122000
# 30               https://www.flickr.com/photos/tayac/  55.950000 -3.128000
# 31               https://www.flickr.com/photos/tayac/  55.951000 -3.126000
# 32               https://www.flickr.com/photos/tayac/  55.951000 -3.121000
#
#                                                 Image  Unnamed: 11  \
# 0   https://images.squarespace-cdn.com/content/v1/...          NaN
# 1   https://www.edinburghnews.scotsman.com/images-...          NaN
# 2                     https://i.imgur.com/CWdSlst.jpg          NaN
# 3   https://edwinglucas.com/uploads/3/5/5/6/355692...          NaN
# 4   https://nen.press/wp-content/uploads/2019/09/N...          NaN
# 5   http://nen.press/wp-content/uploads/2019/09/Ca...          NaN
# 6   https://nen.press/wp-content/uploads/2019/09/W...          NaN
# 7   https://i2-prod.edinburghlive.co.uk/incoming/a...          NaN
# 8   https://i2-prod.edinburghlive.co.uk/incoming/a...          NaN
# 9   https://i2-prod.edinburghlive.co.uk/incoming/a...          NaN
# 10  https://i2-prod.edinburghlive.co.uk/incoming/a...          NaN
# 11  https://images.squarespace-cdn.com/content/v1/...          NaN
# 12  https://i2-prod.edinburghlive.co.uk/incoming/a...          NaN
# 13  https://i2-prod.edinburghlive.co.uk/incoming/a...          NaN
# 14  https://images.squarespace-cdn.com/content/v1/...          NaN
# 15  https://images.squarespace-cdn.com/content/v1/...          NaN
# 16  https://images.squarespace-cdn.com/content/v1/...          NaN
# 17  https://leithdockersclub.co.uk/wp-content/uplo...          NaN
# 18  https://scontent-lga3-1.cdninstagram.com/v/t51...          NaN
# 19  https://images.squarespace-cdn.com/content/v1/...          NaN
# 20  https://images.squarespace-cdn.com/content/v1/...          NaN
# 21  http://3.bp.blogspot.com/-arHKfickdtw/Vo54MTeQ...          NaN
# 22  https://images.squarespace-cdn.com/content/v1/...          NaN
# 23  http://www.friendsofroseburnpark.org.uk/files/...          NaN
# 24  http://www.friendsofroseburnpark.org.uk/2011/0...          NaN
# 25                https://i.redd.it/5n700u4pjnf51.jpg          NaN
# 26  https://grrrrr-inc.com/wp-content/uploads/2020...          NaN
# 27  https://grrrrr-inc.com/wp-content/uploads/2020...          NaN
# 28  https://grrrrr-inc.com/wp-content/uploads/2019...          NaN
# 29  https://scontent-lht6-1.xx.fbcdn.net/v/t1.0-9/...          NaN
# 30  https://scontent-lhr8-1.xx.fbcdn.net/v/t1.0-9/...          NaN
# 31  https://scontent-lht6-1.xx.fbcdn.net/v/t1.0-9/...          NaN
# 32  https://scontent-lht6-1.xx.fbcdn.net/v/t1.0-9/...          NaN
#
#                                           Unnamed: 12
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20  https://streetartnews.net/2013/09/streetart-by...
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN

# %%
print (PublicData.dtypes)
print (StreetData.dtypes)
# Out:
# Title / subject       object
# y                     object
# x                    float64
# Date                  object
# Location              object
# Artist / designer     object
# Type                  object
# Material              object
# Dimensions            object
# Designation           object
# Collection            object
# Notes                 object
# Images                object
# Source                object
# dtype: object
# name            object
# Category        object
# State           object
# Address         object
# Artist          object
# Summary         object
# Year           float64
# website         object
# Y              float64
# X              float64
# Image           object
# Unnamed: 11    float64
# Unnamed: 12     object
# dtype: object

# %% [markdown]
# The date in public art.csv is complex with different formats, like some showing date with '/', while others showing with '-'. Also, according to our goal, the data we need is the year. So we decided to only keep the year part.

# %%
PublicData['Date'] = PublicData['Date'].str.split('(').str[0]
PublicData['Date'] = PublicData['Date'].str.split('-').str[0]
PublicData['Date'] = PublicData['Date'].str.split('–').str[0]
PublicData['Date'] = PublicData['Date'].str.split('/').str[0]

# %%
PublicData['Date'] = PublicData['Date'].str.strip('c.')
PublicData['Date'] = PublicData['Date'].str.strip('Erected ')

# %%
PublicData['Date'] = PublicData['Date'].str.split('.').str[0]
PublicData['Date']
print(PublicData.dtypes)
# Out:
# Title / subject       object
# y                     object
# x                    float64
# Date                  object
# Location              object
# Artist / designer     object
# Type                  object
# Material              object
# Dimensions            object
# Designation           object
# Collection            object
# Notes                 object
# Images                object
# Source                object
# dtype: object

# %% [markdown]
# Change the year object format into the float which is easy to select from centuries by centuries.

# %%
#data['y'] = pd.to_numeric(data['y']) 
PublicData['y'] = PublicData['y'].str.replace(',','').astype(float)
print(PublicData["y"].dtypes)
#data
# Out:
# float64

# %%
PublicData['Date'] = PublicData['Date'].str.replace('s','').astype(float)
print(PublicData["Date"].dtypes)
# Out:
# float64

# %% [markdown]
# Clean the data about missing data(remove Holodomor Memorial Stone & Gulliver in Edinburgh)

# %%
PublicData=PublicData.drop(PublicData[(PublicData['Title / subject']=='Holodomor Memorial Stone')].index)
PublicData=PublicData.drop(PublicData[(PublicData['Title / subject']=='Gulliver in Edinburgh')].index)
PublicData
# Out:
#                           Title / subject          y         x    Date  \
# 0               Monument to John Playfair  55.954800 -3.183000  1825.0
# 1              Monument to Dugald Stewart  55.954500 -3.184500  1831.0
# 2                Monument to Robert Burns  55.953500 -3.178300  1831.0
# 3             Political Martyrs' Monument  55.953400 -3.185800  1844.0
# 4    Scottish-American Soldiers' Monument  55.953500 -3.186100  1893.0
# ..                                    ...        ...       ...     ...
# 142                  Crew Building Relief  55.923065 -3.177520  1926.0
# 143                 Startled Horse Rising  55.864532 -3.200328  1833.0
# 144                         William Dick   55.865794 -3.201039  1883.0
# 145                Sprinting Afghan Hound  55.864975 -3.201746  1996.0
# 146                                Canter  55.865174 -3.200375  2017.0
#
#              Location                     Artist / designer  \
# 0                 NaN                William Henry Playfair
# 1                 NaN                William Henry Playfair
# 2                 NaN                       Thomas Hamilton
# 3                 NaN                       Thomas Hamilton
# 4                 NaN                  George Edwin Bissell
# ..                ...                                   ...
# 142  King's Buildings  Charles d'Orville Pilkington-Jackson
# 143       Easter Bush                      Sir John Steell
# 144       Easter Bush                           John Rhind
# 145       Easter Bush                Mathew Lane Sanderson
# 146       Easter Bush                           Andy Scott
#
#                                            Type  \
# 0              Square-plan Greek Doric monument
# 1    Circular Greek-revival Corinthian monument
# 2    Circular Greek-revival Corinthian monument
# 3                                       Obelisk
# 4              Statue with subsidiary sculpture
# ..                                          ...
# 142                                         NaN
# 143                                         NaN
# 144                                         NaN
# 145                                         NaN
# 146                                         NaN
#
#                                    Material Dimensions  \
# 0                           Polished ashlar        NaN
# 1                           Polished ashlar        NaN
# 2                          Ashlar sandstone        NaN
# 3                                       NaN        NaN
# 4    Bronze figures on red granite pedestal        NaN
# ..                                      ...        ...
# 142                                     NaN        NaN
# 143                                     NaN        NaN
# 144                                   Stone        NaN
# 145                                  Bronze        NaN
# 146                                     NaN        NaN
#
#                                            Designation  \
# 0                                    Category A-listed
# 1                                    Category A-listed
# 2                                    Category A-listed
# 3    Category A-listed (as part of Old Calton Buria...
# 4    Category A-listed (as part of Old Calton Buria...
# ..                                                 ...
# 142                                                NaN
# 143                                                NaN
# 144                                                NaN
# 145                                                NaN
# 146                                                NaN
#
#                                    Collection  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 142  University of Edinburgh  Art Collection
# 143  University of Edinburgh  Art Collection
# 144  University of Edinburgh  Art Collection
# 145  University of Edinburgh  Art Collection
# 146  University of Edinburgh  Art Collection
#
#                                                  Notes  \
# 0         Incorporated in observatory compound wall[1]
# 1    Based on the Choragic Monument of Lysicrates i...
# 2    Based on the Choragic Monument of Lysicrates i...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 142  The figurative relief carving to the building'...
# 143  Stone sculpture of a horse, lying on the groun...
# 144  Sculpture of former Vetinary surgeon and found...
# 145  Sprinting afghan hound, hair flowing behind it...
# 146                                                NaN
#
#                                                 Images  \
# 0    https://upload.wikimedia.org/wikipedia/commons...
# 1    https://upload.wikimedia.org/wikipedia/commons...
# 2    https://upload.wikimedia.org/wikipedia/commons...
# 3    https://upload.wikimedia.org/wikipedia/commons...
# 4    https://upload.wikimedia.org/wikipedia/commons...
# ..                                                 ...
# 142  https://images.is.ed.ac.uk/luna/servlet/iiif/U...
# 143  https://images.is.ed.ac.uk/luna/servlet/iiif/U...
# 144  https://images.is.ed.ac.uk/luna/servlet/iiif/U...
# 145  https://images.is.ed.ac.uk/luna/servlet/iiif/U...
# 146  https://www.roslininnovationcentre.com/assets/...
#
#                                                 Source
# 0    https://en.wikipedia.org/wiki/List_of_public_a...
# 1    https://en.wikipedia.org/wiki/List_of_public_a...
# 2    https://en.wikipedia.org/wiki/List_of_public_a...
# 3    https://en.wikipedia.org/wiki/List_of_public_a...
# 4    https://en.wikipedia.org/wiki/List_of_public_a...
# ..                                                 ...
# 142                                                NaN
# 143                                                NaN
# 144                                                NaN
# 145                                                NaN
# 146                                                NaN
#
# [145 rows x 14 columns]

# %%
PublicData.drop(['Location', 'Artist / designer',
'Type', 'Material','Dimensions', 'Designation','Collection','Notes','Images','Source'], axis=1, inplace = True)

PublicData
# Out:
#                           Title / subject          y         x    Date
# 0               Monument to John Playfair  55.954800 -3.183000  1825.0
# 1              Monument to Dugald Stewart  55.954500 -3.184500  1831.0
# 2                Monument to Robert Burns  55.953500 -3.178300  1831.0
# 3             Political Martyrs' Monument  55.953400 -3.185800  1844.0
# 4    Scottish-American Soldiers' Monument  55.953500 -3.186100  1893.0
# ..                                    ...        ...       ...     ...
# 142                  Crew Building Relief  55.923065 -3.177520  1926.0
# 143                 Startled Horse Rising  55.864532 -3.200328  1833.0
# 144                         William Dick   55.865794 -3.201039  1883.0
# 145                Sprinting Afghan Hound  55.864975 -3.201746  1996.0
# 146                                Canter  55.865174 -3.200375  2017.0
#
# [145 rows x 4 columns]

# %%
PublicData['Sort']='Public art'
PublicData
# Out:
#                           Title / subject          y         x    Date  \
# 0               Monument to John Playfair  55.954800 -3.183000  1825.0
# 1              Monument to Dugald Stewart  55.954500 -3.184500  1831.0
# 2                Monument to Robert Burns  55.953500 -3.178300  1831.0
# 3             Political Martyrs' Monument  55.953400 -3.185800  1844.0
# 4    Scottish-American Soldiers' Monument  55.953500 -3.186100  1893.0
# ..                                    ...        ...       ...     ...
# 142                  Crew Building Relief  55.923065 -3.177520  1926.0
# 143                 Startled Horse Rising  55.864532 -3.200328  1833.0
# 144                         William Dick   55.865794 -3.201039  1883.0
# 145                Sprinting Afghan Hound  55.864975 -3.201746  1996.0
# 146                                Canter  55.865174 -3.200375  2017.0
#
#            Sort
# 0    Public art
# 1    Public art
# 2    Public art
# 3    Public art
# 4    Public art
# ..          ...
# 142  Public art
# 143  Public art
# 144  Public art
# 145  Public art
# 146  Public art
#
# [145 rows x 5 columns]

# %%
StreetData.drop(['Category','State',
'Address', 'Artist', 'Summary','website','Image','Unnamed: 11','Unnamed: 12'], axis=1, inplace = True)
StreetData
# Out:
#                                      name    Year          Y         X
# 0                     Leith History Mural     NaN  55.975789 -3.179434
# 1                     Horne Terrace Mural     NaN  55.939979 -3.213681
# 2   Colinton Station and Tunnel (site of)     NaN  55.907897 -3.260054
# 3                       Spylaw park mural     NaN  55.907430 -3.260413
# 4                          Never Ordinary     NaN  55.947394 -3.192042
# 5                            Capita Mural     NaN  55.945689 -3.211781
# 6                          Wildlife Mural     NaN  55.918382 -3.299983
# 7                              Etza Skull     NaN  55.979919 -3.185874
# 8                        Eduardo Paolozzi     NaN  55.974585 -3.172151
# 9                      Gifford Park Mural     NaN  55.942136 -3.182363
# 10                  Bongo Club Gate Mural     NaN  55.948197 -3.192164
# 11                              Abbeyhill     NaN  55.954961 -3.172947
# 12                        Studio 24 mural     NaN  55.952640 -3.179313
# 13        4 Doors Down Street Art Project     NaN  55.974766 -3.168192
# 14                     The acuatic Leith      NaN  55.968044 -3.170300
# 15                          Wronger Rites  2015.0  55.964819 -3.174445
# 16                         Untitled Mural  2016.0  55.968598 -3.173372
# 17               Leith Dockers Club Mural  2013.0  55.970740 -3.170118
# 18                         Untitled Mural  1984.0  55.973644 -3.170588
# 19                Too Much Fun Club Mural     NaN  55.967603 -3.179904
# 20                  The Seven Deadly Sins     NaN  55.965529 -3.175854
# 21                        Swanfield Mural  1986.0  55.971693 -3.176815
# 22     Scotland, together, persevere, NHS  2020.0  55.962692 -3.178664
# 23                          Armoury mural  2019.0  55.945211 -3.240524
# 24              Graffiti in Roseburn Park  2011.0  55.945270 -3.240296
# 25                            Free Speech  2020.0  55.926331 -3.269629
# 26                                  Unity  2020.0  55.966275 -3.175770
# 27                            The Protest  2020.0  55.967740 -3.173990
# 28                               Poseidon  2019.0  55.980129 -3.218357
# 29                 Figgate Park Wild life  2015.0  55.951000 -3.122000
# 30                 Figgate Park Wild life  2015.0  55.950000 -3.128000
# 31                 Figgate Park Wild life  2015.0  55.951000 -3.126000
# 32                 Figgate Park Wild life  2015.0  55.951000 -3.121000

# %%
StreetData['Sort']='Street art'
StreetData
# Out:
#                                      name    Year          Y         X  \
# 0                     Leith History Mural     NaN  55.975789 -3.179434
# 1                     Horne Terrace Mural     NaN  55.939979 -3.213681
# 2   Colinton Station and Tunnel (site of)     NaN  55.907897 -3.260054
# 3                       Spylaw park mural     NaN  55.907430 -3.260413
# 4                          Never Ordinary     NaN  55.947394 -3.192042
# 5                            Capita Mural     NaN  55.945689 -3.211781
# 6                          Wildlife Mural     NaN  55.918382 -3.299983
# 7                              Etza Skull     NaN  55.979919 -3.185874
# 8                        Eduardo Paolozzi     NaN  55.974585 -3.172151
# 9                      Gifford Park Mural     NaN  55.942136 -3.182363
# 10                  Bongo Club Gate Mural     NaN  55.948197 -3.192164
# 11                              Abbeyhill     NaN  55.954961 -3.172947
# 12                        Studio 24 mural     NaN  55.952640 -3.179313
# 13        4 Doors Down Street Art Project     NaN  55.974766 -3.168192
# 14                     The acuatic Leith      NaN  55.968044 -3.170300
# 15                          Wronger Rites  2015.0  55.964819 -3.174445
# 16                         Untitled Mural  2016.0  55.968598 -3.173372
# 17               Leith Dockers Club Mural  2013.0  55.970740 -3.170118
# 18                         Untitled Mural  1984.0  55.973644 -3.170588
# 19                Too Much Fun Club Mural     NaN  55.967603 -3.179904
# 20                  The Seven Deadly Sins     NaN  55.965529 -3.175854
# 21                        Swanfield Mural  1986.0  55.971693 -3.176815
# 22     Scotland, together, persevere, NHS  2020.0  55.962692 -3.178664
# 23                          Armoury mural  2019.0  55.945211 -3.240524
# 24              Graffiti in Roseburn Park  2011.0  55.945270 -3.240296
# 25                            Free Speech  2020.0  55.926331 -3.269629
# 26                                  Unity  2020.0  55.966275 -3.175770
# 27                            The Protest  2020.0  55.967740 -3.173990
# 28                               Poseidon  2019.0  55.980129 -3.218357
# 29                 Figgate Park Wild life  2015.0  55.951000 -3.122000
# 30                 Figgate Park Wild life  2015.0  55.950000 -3.128000
# 31                 Figgate Park Wild life  2015.0  55.951000 -3.126000
# 32                 Figgate Park Wild life  2015.0  55.951000 -3.121000
#
#           Sort
# 0   Street art
# 1   Street art
# 2   Street art
# 3   Street art
# 4   Street art
# 5   Street art
# 6   Street art
# 7   Street art
# 8   Street art
# 9   Street art
# 10  Street art
# 11  Street art
# 12  Street art
# 13  Street art
# 14  Street art
# 15  Street art
# 16  Street art
# 17  Street art
# 18  Street art
# 19  Street art
# 20  Street art
# 21  Street art
# 22  Street art
# 23  Street art
# 24  Street art
# 25  Street art
# 26  Street art
# 27  Street art
# 28  Street art
# 29  Street art
# 30  Street art
# 31  Street art
# 32  Street art

# %%
PublicData.rename(columns={"Title / subject":"Name"}, inplace=True)
PublicData
# Out:
#                                      Name          y         x    Date  \
# 0               Monument to John Playfair  55.954800 -3.183000  1825.0
# 1              Monument to Dugald Stewart  55.954500 -3.184500  1831.0
# 2                Monument to Robert Burns  55.953500 -3.178300  1831.0
# 3             Political Martyrs' Monument  55.953400 -3.185800  1844.0
# 4    Scottish-American Soldiers' Monument  55.953500 -3.186100  1893.0
# ..                                    ...        ...       ...     ...
# 142                  Crew Building Relief  55.923065 -3.177520  1926.0
# 143                 Startled Horse Rising  55.864532 -3.200328  1833.0
# 144                         William Dick   55.865794 -3.201039  1883.0
# 145                Sprinting Afghan Hound  55.864975 -3.201746  1996.0
# 146                                Canter  55.865174 -3.200375  2017.0
#
#            Sort
# 0    Public art
# 1    Public art
# 2    Public art
# 3    Public art
# 4    Public art
# ..          ...
# 142  Public art
# 143  Public art
# 144  Public art
# 145  Public art
# 146  Public art
#
# [145 rows x 5 columns]

# %%
StreetData.rename(columns = {"name": "Name", "Year":"Date","Y":"y","X":"x"},  inplace=True)
StreetData
# Out:
#                                      Name    Date          y         x  \
# 0                     Leith History Mural     NaN  55.975789 -3.179434
# 1                     Horne Terrace Mural     NaN  55.939979 -3.213681
# 2   Colinton Station and Tunnel (site of)     NaN  55.907897 -3.260054
# 3                       Spylaw park mural     NaN  55.907430 -3.260413
# 4                          Never Ordinary     NaN  55.947394 -3.192042
# 5                            Capita Mural     NaN  55.945689 -3.211781
# 6                          Wildlife Mural     NaN  55.918382 -3.299983
# 7                              Etza Skull     NaN  55.979919 -3.185874
# 8                        Eduardo Paolozzi     NaN  55.974585 -3.172151
# 9                      Gifford Park Mural     NaN  55.942136 -3.182363
# 10                  Bongo Club Gate Mural     NaN  55.948197 -3.192164
# 11                              Abbeyhill     NaN  55.954961 -3.172947
# 12                        Studio 24 mural     NaN  55.952640 -3.179313
# 13        4 Doors Down Street Art Project     NaN  55.974766 -3.168192
# 14                     The acuatic Leith      NaN  55.968044 -3.170300
# 15                          Wronger Rites  2015.0  55.964819 -3.174445
# 16                         Untitled Mural  2016.0  55.968598 -3.173372
# 17               Leith Dockers Club Mural  2013.0  55.970740 -3.170118
# 18                         Untitled Mural  1984.0  55.973644 -3.170588
# 19                Too Much Fun Club Mural     NaN  55.967603 -3.179904
# 20                  The Seven Deadly Sins     NaN  55.965529 -3.175854
# 21                        Swanfield Mural  1986.0  55.971693 -3.176815
# 22     Scotland, together, persevere, NHS  2020.0  55.962692 -3.178664
# 23                          Armoury mural  2019.0  55.945211 -3.240524
# 24              Graffiti in Roseburn Park  2011.0  55.945270 -3.240296
# 25                            Free Speech  2020.0  55.926331 -3.269629
# 26                                  Unity  2020.0  55.966275 -3.175770
# 27                            The Protest  2020.0  55.967740 -3.173990
# 28                               Poseidon  2019.0  55.980129 -3.218357
# 29                 Figgate Park Wild life  2015.0  55.951000 -3.122000
# 30                 Figgate Park Wild life  2015.0  55.950000 -3.128000
# 31                 Figgate Park Wild life  2015.0  55.951000 -3.126000
# 32                 Figgate Park Wild life  2015.0  55.951000 -3.121000
#
#           Sort
# 0   Street art
# 1   Street art
# 2   Street art
# 3   Street art
# 4   Street art
# 5   Street art
# 6   Street art
# 7   Street art
# 8   Street art
# 9   Street art
# 10  Street art
# 11  Street art
# 12  Street art
# 13  Street art
# 14  Street art
# 15  Street art
# 16  Street art
# 17  Street art
# 18  Street art
# 19  Street art
# 20  Street art
# 21  Street art
# 22  Street art
# 23  Street art
# 24  Street art
# 25  Street art
# 26  Street art
# 27  Street art
# 28  Street art
# 29  Street art
# 30  Street art
# 31  Street art
# 32  Street art

# %%
print(PublicData.dtypes)
# Out:
# Name     object
# y       float64
# x       float64
# Date    float64
# Sort     object
# dtype: object

# %%
pd.concat([PublicData,StreetData],axis=0)
# Out:
#                                     Name          y         x    Date  \
# 0              Monument to John Playfair  55.954800 -3.183000  1825.0
# 1             Monument to Dugald Stewart  55.954500 -3.184500  1831.0
# 2               Monument to Robert Burns  55.953500 -3.178300  1831.0
# 3            Political Martyrs' Monument  55.953400 -3.185800  1844.0
# 4   Scottish-American Soldiers' Monument  55.953500 -3.186100  1893.0
# ..                                   ...        ...       ...     ...
# 28                              Poseidon  55.980129 -3.218357  2019.0
# 29                Figgate Park Wild life  55.951000 -3.122000  2015.0
# 30                Figgate Park Wild life  55.950000 -3.128000  2015.0
# 31                Figgate Park Wild life  55.951000 -3.126000  2015.0
# 32                Figgate Park Wild life  55.951000 -3.121000  2015.0
#
#           Sort
# 0   Public art
# 1   Public art
# 2   Public art
# 3   Public art
# 4   Public art
# ..         ...
# 28  Street art
# 29  Street art
# 30  Street art
# 31  Street art
# 32  Street art
#
# [178 rows x 5 columns]

# %%
ArtData=pd.concat([PublicData,StreetData],axis=0)

# %%
ArtData.dropna(axis=0, how='any')
ArtData
# Out:
#                                     Name          y         x    Date  \
# 0              Monument to John Playfair  55.954800 -3.183000  1825.0
# 1             Monument to Dugald Stewart  55.954500 -3.184500  1831.0
# 2               Monument to Robert Burns  55.953500 -3.178300  1831.0
# 3            Political Martyrs' Monument  55.953400 -3.185800  1844.0
# 4   Scottish-American Soldiers' Monument  55.953500 -3.186100  1893.0
# ..                                   ...        ...       ...     ...
# 28                              Poseidon  55.980129 -3.218357  2019.0
# 29                Figgate Park Wild life  55.951000 -3.122000  2015.0
# 30                Figgate Park Wild life  55.950000 -3.128000  2015.0
# 31                Figgate Park Wild life  55.951000 -3.126000  2015.0
# 32                Figgate Park Wild life  55.951000 -3.121000  2015.0
#
#           Sort
# 0   Public art
# 1   Public art
# 2   Public art
# 3   Public art
# 4   Public art
# ..         ...
# 28  Street art
# 29  Street art
# 30  Street art
# 31  Street art
# 32  Street art
#
# [178 rows x 5 columns]

# %%
print(ArtData.dtypes)
# Out:
# Name     object
# y       float64
# x       float64
# Date    float64
# Sort     object
# dtype: object

# %%
ArtData.to_csv('Publicart final.csv')

# %%
ArtData1700=ArtData.loc[ArtData['Date']<=1800]
ArtData1700
# Out:
#                          Name          y         x    Date        Sort
# 15  Monument to Carl Linnaeus  55.966842 -3.207415  1778.0  Public art
# 42                 Charles II  55.949200 -3.190500  1685.0  Public art

# %%
ArtData1700.to_csv('Publicart final1700.csv')

# %%
ArtData1800=ArtData.loc[(ArtData['Date']<=1900) & (ArtData['Date']>1800)]
ArtData1800
# Out:
#                                                   Name          y         x  \
# 0                            Monument to John Playfair  55.954800 -3.183000
# 1                           Monument to Dugald Stewart  55.954500 -3.184500
# 2                             Monument to Robert Burns  55.953500 -3.178300
# 3                          Political Martyrs' Monument  55.953400 -3.185800
# 4                 Scottish-American Soldiers' Monument  55.953500 -3.186100
# 7                                Covenanters’ Memorial  55.904680 -3.238737
# 13                   Mausoleum of William Henry Miller  55.957100 -3.137200
# 23                                        Robert Burns  55.975400 -3.166800
# 27                     John Hope, 4th Earl of Hopetoun  55.954500 -3.191700
# 28     Monument to Henry Dundas, 1st Viscount Melville  55.954200 -3.193200
# 29                                           George IV  55.953500 -3.197300
# 30                            William Pitt the Younger  55.953000 -3.200400
# 31                  Memorial to Albert, Prince Consort  55.951800 -3.207700
# 32                      Monument to Catherine Sinclair  55.953200 -3.207600
# 33                                     Thomas Chalmers  55.952500 -3.203500
# 43                            Alexander and Bucephalus  55.950100 -3.190300
# 44           Prince Frederick, Duke of York and Albany  55.948900 -3.197900
# 45                           78th Highlanders Memorial  55.949000 -3.196900
# 46                           Greyfriars Bobby Fountain  55.946900 -3.191300
# 47               Monument to Colonel Douglas Mackenzie  55.948900 -3.197400
# 48                           72nd Highlanders Memorial  55.948900 -3.198100
# 49   Queensberry Memorial to Walter Montagu Douglas...  55.949500 -3.191700
# 50                                    William Chambers  55.947380 -3.189790
# 51                                           John Knox  55.949600 -3.195100
# 67                                    Sir Walter Scott  55.952399 -3.193304
# 68            Arthur Wellesley, 1st Duke of Wellington  55.953500 -3.189200
# 69                                        Allan Ramsay  55.951700 -3.197300
# 70   The genius of architecture crowning the theory...  55.951000 -3.198300
# 71                                       Ross Fountain  55.950050 -3.202994
# 72                                         John Wilson  55.952100 -3.195100
# 73                                   David Livingstone  55.952500 -3.192700
# 74                                          Adam Black  55.952200 -3.194400
# 75                             Sir James Young Simpson  55.950400 -3.205000
# 76            Memorial to Dean Edward Bannerman Ramsay  55.950264 -3.205931
# 87                                          James Watt  55.909300 -3.320030
# 99                        Middle Meadow Walk Gatepiers  55.945300 -3.191100
# 100       Melville Drive (east end) Ornamental Pillars  55.940300 -3.183300
# 101              Memorial to Archbishop Archibald Tait  55.944818 -3.190430
# 102                              Brassfounders’ Pillar  55.946000 -3.185400
# 103                                    Masons’ Pillars  55.942000 -3.200300
# 104                       Prince Albert Victor Sundial  55.941800 -3.198800
# 105                              McEwan Lantern Pillar  55.945346 -3.188812
# 108                           Statue of David Brewster  55.921773 -3.171760
# 110               Robert Dundas, 2nd Viscount Melville  55.949700 -3.213900
# 143                              Startled Horse Rising  55.864532 -3.200328
# 144                                      William Dick   55.865794 -3.201039
#
#        Date        Sort
# 0    1825.0  Public art
# 1    1831.0  Public art
# 2    1831.0  Public art
# 3    1844.0  Public art
# 4    1893.0  Public art
# 7    1885.0  Public art
# 13   1848.0  Public art
# 23   1897.0  Public art
# 27   1834.0  Public art
# 28   1817.0  Public art
# 29   1825.0  Public art
# 30   1831.0  Public art
# 31   1862.0  Public art
# 32   1866.0  Public art
# 33   1869.0  Public art
# 43   1829.0  Public art
# 44   1837.0  Public art
# 45   1861.0  Public art
# 46   1873.0  Public art
# 47   1875.0  Public art
# 48   1882.0  Public art
# 49   1885.0  Public art
# 50   1888.0  Public art
# 51   1896.0  Public art
# 67   1848.0  Public art
# 68   1848.0  Public art
# 69   1850.0  Public art
# 70   1862.0  Public art
# 71   1862.0  Public art
# 72   1863.0  Public art
# 73   1875.0  Public art
# 74   1876.0  Public art
# 75   1877.0  Public art
# 76   1877.0  Public art
# 87   1854.0  Public art
# 99   1840.0  Public art
# 100  1880.0  Public art
# 101  1884.0  Public art
# 102  1886.0  Public art
# 103  1886.0  Public art
# 104  1886.0  Public art
# 105  1890.0  Public art
# 108  1877.0  Public art
# 110  1857.0  Public art
# 143  1833.0  Public art
# 144  1883.0  Public art

# %%
ArtData1800.to_csv('Publicart final1800.csv')

# %%
ArtData1900=ArtData.loc[(ArtData['Date']<=2000) & (ArtData['Date']>1900)]
ArtData1900
# Out:
#                         Name          y         x    Date        Sort
# 16   Ascending Form (Gloria)  55.964916 -3.204378  1958.0  Public art
# 17    Rock Form (Porthcurno)  55.964718 -3.206889  1964.0  Public art
# 18               Umbra solis  55.965080 -3.210991  1975.0  Public art
# 19         Slate, Hole, Wall  55.962917 -3.211345  1990.0  Public art
# 20                      Cone  55.965110 -3.209825  1990.0  Public art
# ..                       ...        ...       ...     ...         ...
# 141                 Geology   55.924015 -3.174405  1931.0  Public art
# 142     Crew Building Relief  55.923065 -3.177520  1926.0  Public art
# 145   Sprinting Afghan Hound  55.864975 -3.201746  1996.0  Public art
# 18            Untitled Mural  55.973644 -3.170588  1984.0  Street art
# 21           Swanfield Mural  55.971693 -3.176815  1986.0  Street art
#
# [61 rows x 5 columns]

# %%
ArtData1900.to_csv('Publicart final1900.csv')

# %%
ArtData2000=ArtData.loc[ArtData['Date']>2000]
ArtData2000
# Out:
#                                                   Name          y         x  \
# 5                            Stones of Scotland Circle  55.954900 -3.174500
# 8                   Memorial to Robert Louis Stevenson  55.908597 -3.256297
# 9           Memorial to Army pipers killed in conflict  55.909542 -3.249274
# 10   Alan Breck Stewart & David Balfour. Characters...  55.945030 -3.249841
# 12                         Nils Olav (penguin soldier)  55.944117 -3.271337
# 14                                    The Cramond Fish  55.979722 -3.294227
# 25                                             6 Times  55.983600 -3.176360
# 38                                     Dreaming Spires  55.956344 -3.186225
# 39                                    Lion of Scotland  55.954623 -3.193084
# 40                                 James Clerk Maxwell  55.954053 -3.194381
# 61                                          Adam Smith  55.949764 -3.190069
# 62                                    Robert Fergusson  55.951574 -3.179363
# 63                                     James Braidwood  55.949495 -3.190013
# 64                                       Work No. 1059  55.951215 -3.188660
# 65                              William Henry Playfair  55.947570 -3.188930
# 84                          Bum the Dog (of San Diego)  55.948417 -3.203388
# 85                   Wojtek (Voytek), the Soldier Bear  55.950833 -3.202028
# 86                     Lulla-Bye (Children’s Memorial)  55.950939 -3.198579
# 106                                    Rhinoceros head  55.944755 -3.187452
# 107                     Bite on the Haynes Nano Stage   55.944579 -3.187582
# 118                                           Landform  55.951288 -3.227125
# 119                                     Macduff Circle  55.951917 -3.223340
# 120                                            6 Times  55.951182 -3.225086
# 121   The Next Big Thing…Is A Series of Little Things   55.945393 -3.189116
# 122                               Mesostic Interleaved  55.942908 -3.189075
# 123  The Basic Material Is Not the Word But the Let...  55.942748 -3.188550
# 130                            Untitled (Sucker Darts)  55.945175 -3.198524
# 136                                            Unknown  55.937365 -3.169483
# 146                                             Canter  55.865174 -3.200375
# 15                                       Wronger Rites  55.964819 -3.174445
# 16                                      Untitled Mural  55.968598 -3.173372
# 17                            Leith Dockers Club Mural  55.970740 -3.170118
# 22                  Scotland, together, persevere, NHS  55.962692 -3.178664
# 23                                       Armoury mural  55.945211 -3.240524
# 24                           Graffiti in Roseburn Park  55.945270 -3.240296
# 25                                         Free Speech  55.926331 -3.269629
# 26                                               Unity  55.966275 -3.175770
# 27                                         The Protest  55.967740 -3.173990
# 28                                            Poseidon  55.980129 -3.218357
# 29                              Figgate Park Wild life  55.951000 -3.122000
# 30                              Figgate Park Wild life  55.950000 -3.128000
# 31                              Figgate Park Wild life  55.951000 -3.126000
# 32                              Figgate Park Wild life  55.951000 -3.121000
#
#        Date        Sort
# 5    2002.0  Public art
# 8    2013.0  Public art
# 9    2013.0  Public art
# 10   2004.0  Public art
# 12   2005.0  Public art
# 14   2009.0  Public art
# 25   2010.0  Public art
# 38   2005.0  Public art
# 39   2006.0  Public art
# 40   2006.0  Public art
# 61   2003.0  Public art
# 62   2004.0  Public art
# 63   2006.0  Public art
# 64   2011.0  Public art
# 65   2016.0  Public art
# 84   2008.0  Public art
# 85   2015.0  Public art
# 86   2019.0  Public art
# 106  2012.0  Public art
# 107  2012.0  Public art
# 118  2001.0  Public art
# 119  2002.0  Public art
# 120  2010.0  Public art
# 121  2017.0  Public art
# 122  2009.0  Public art
# 123  2017.0  Public art
# 130  2016.0  Public art
# 136  2007.0  Public art
# 146  2017.0  Public art
# 15   2015.0  Street art
# 16   2016.0  Street art
# 17   2013.0  Street art
# 22   2020.0  Street art
# 23   2019.0  Street art
# 24   2011.0  Street art
# 25   2020.0  Street art
# 26   2020.0  Street art
# 27   2020.0  Street art
# 28   2019.0  Street art
# 29   2015.0  Street art
# 30   2015.0  Street art
# 31   2015.0  Street art
# 32   2015.0  Street art

# %%
ArtData2000.to_csv('Publicart final2000.csv')

# %%
ArtDataFinal=pd.concat([ArtData1700,ArtData1800,ArtData1900,ArtData2000],axis=0)
ArtDataFinal
# Out:
#                           Name          y         x    Date        Sort
# 15   Monument to Carl Linnaeus  55.966842 -3.207415  1778.0  Public art
# 42                  Charles II  55.949200 -3.190500  1685.0  Public art
# 0    Monument to John Playfair  55.954800 -3.183000  1825.0  Public art
# 1   Monument to Dugald Stewart  55.954500 -3.184500  1831.0  Public art
# 2     Monument to Robert Burns  55.953500 -3.178300  1831.0  Public art
# ..                         ...        ...       ...     ...         ...
# 28                    Poseidon  55.980129 -3.218357  2019.0  Street art
# 29      Figgate Park Wild life  55.951000 -3.122000  2015.0  Street art
# 30      Figgate Park Wild life  55.950000 -3.128000  2015.0  Street art
# 31      Figgate Park Wild life  55.951000 -3.126000  2015.0  Street art
# 32      Figgate Park Wild life  55.951000 -3.121000  2015.0  Street art
#
# [152 rows x 5 columns]

# %%
ArtDataFinal2 = ArtDataFinal.set_index('Name', inplace=False)
ArtDataFinal2
# Out:
#                                     y         x    Date        Sort
# Name
# Monument to Carl Linnaeus   55.966842 -3.207415  1778.0  Public art
# Charles II                  55.949200 -3.190500  1685.0  Public art
# Monument to John Playfair   55.954800 -3.183000  1825.0  Public art
# Monument to Dugald Stewart  55.954500 -3.184500  1831.0  Public art
# Monument to Robert Burns    55.953500 -3.178300  1831.0  Public art
# ...                               ...       ...     ...         ...
# Poseidon                    55.980129 -3.218357  2019.0  Street art
# Figgate Park Wild life      55.951000 -3.122000  2015.0  Street art
# Figgate Park Wild life      55.950000 -3.128000  2015.0  Street art
# Figgate Park Wild life      55.951000 -3.126000  2015.0  Street art
# Figgate Park Wild life      55.951000 -3.121000  2015.0  Street art
#
# [152 rows x 4 columns]

# %%
ArtDataFinal3=ArtDataFinal2.reset_index()
ArtDataFinal3
# Out:
#                            Name          y         x    Date        Sort
# 0     Monument to Carl Linnaeus  55.966842 -3.207415  1778.0  Public art
# 1                    Charles II  55.949200 -3.190500  1685.0  Public art
# 2     Monument to John Playfair  55.954800 -3.183000  1825.0  Public art
# 3    Monument to Dugald Stewart  55.954500 -3.184500  1831.0  Public art
# 4      Monument to Robert Burns  55.953500 -3.178300  1831.0  Public art
# ..                          ...        ...       ...     ...         ...
# 147                    Poseidon  55.980129 -3.218357  2019.0  Street art
# 148      Figgate Park Wild life  55.951000 -3.122000  2015.0  Street art
# 149      Figgate Park Wild life  55.950000 -3.128000  2015.0  Street art
# 150      Figgate Park Wild life  55.951000 -3.126000  2015.0  Street art
# 151      Figgate Park Wild life  55.951000 -3.121000  2015.0  Street art
#
# [152 rows x 5 columns]

# %%
ArtDataFinal3.to_csv('Publicart final(without year NaN).csv')

# %% [markdown]
# Plot

# %%
EdiMap = folium.Map(location=[ArtDataFinal3['y'].mean(), ArtDataFinal3['x'].mean()], zoom_start=12,
                 # tiles="http://{s}.tile.stamen.com/watercolor/{z}/{x}/{y}.jpg",
                    tiles='Stamen Terrain',
                    attr="default")
marker_cluster = plugins.MarkerCluster().add_to(EdiMap)
display(EdiMap)

#mark points
for name,row in ArtDataFinal3.iterrows():
     folium.Marker([row["y"], row["x"]], popup="{0}:{1}".format(row["Name"], 1)).add_to(marker_cluster) 
display(EdiMap)
EdiMap.save('map.html')
webbrowser.open('map.html')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# True

# %%
num=ArtDataFinal3.shape[0]
lat = np.array(ArtDataFinal3["y"][0:num])                        # 获取维度之维度值
lon = np.array(ArtDataFinal3["x"][0:num])                        # 获取经度值

data1 = [[lat[i],lon[i]] for i in range(num)]    #将数据制作成[lats,lons,weights]的形式

Map_heat = folium.Map(location=[ArtDataFinal3['y'].mean(), ArtDataFinal3['x'].mean()],zoom_start=12)    #绘制Map，开始缩放程度是5倍
HeatMap(data1).add_to(Map_heat)  
display(Map_heat)
Map_heat.save('map2.html')
webbrowser.open('map2.html')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# True

# %%
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt

# %%
chart = sns.kdeplot(ArtDataFinal3['Date'])
chart.set_title('the appearance date distriubtion of arts in Edinburgh')
plt.savefig('the appearance date distriubtion of arts in Edinburgh.png')
plt.show()

# %%
print(ArtData1700.shape[0],
                         ArtData1800.shape[0],
                        ArtData1900.shape[0],
                    ArtData2000.shape[0])
# Out:
# 2 46 61 43

# %%
plt.figure(figsize=(8, 6))                    #画图，大小可自己设置
DateData= {'Date': ['1700','1800', '1900', '2000'],
           'count': [ArtData1700.shape[0],
                         ArtData1800.shape[0],
                        ArtData1900.shape[0],
                    ArtData2000.shape[0]]
           }
dataframe_1 = pd.DataFrame(DateData)
colors = ['salmon', 'sandybrown', 'navajowhite', 'lightcoral']
labels = dataframe_1['count']
x = dataframe_1['Date']
plt.pie(labels, labels=['<1800','1800-1900', '1900-2000', '>2000'], autopct='%1.1f%%',colors=colors)
plt.legend(bbox_to_anchor=(1.01, 1))
plt.title('Year of art distribution')
plt.savefig('Year distribution pie.png')
plt.show()

# %%
sns.scatterplot(x="x", y="y",data=ArtData,color='pink')
plt.title('location scatterplot')
plt.savefig('location distribution scatterplot.png')
plt.show()
